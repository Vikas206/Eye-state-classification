# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import tensorflow.compat.v1 as tf
from sklearn.metrics import confusion_matrix
import numpy as np
from scipy.io import loadmat
import os
from pywt import wavedec
from functools import reduce
from scipy import signal
from scipy.stats import entropy
from scipy.fft import fft, ifft
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tensorflow import keras as K
import matplotlib.pyplot as plt
import scipy
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold,cross_validate
from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape
#from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt;
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.decomposition import PCA
from tensorflow import keras
from sklearn.model_selection import cross_val_score
from tensorflow.keras.layers import Conv1D,Conv2D,Add
from tensorflow.keras.layers import MaxPool1D, MaxPooling2D
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From C:\Users\vikas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 from scipy.io import loadmat
#       5 import os
# ----> 6 from pywt import wavedec
#       7 from functools import reduce
#       8 from scipy import signal
#
# ModuleNotFoundError: No module named 'pywt'

# %%
df = pd.read_csv("EEG_Eye_State_Classification.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14980 entries, 0 to 14979
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AF3           14980 non-null  float64
#  1   F7            14980 non-null  float64
#  2   F3            14980 non-null  float64
#  3   FC5           14980 non-null  float64
#  4   T7            14980 non-null  float64
#  5   P7            14980 non-null  float64
#  6   O1            14980 non-null  float64
#  7   O2            14980 non-null  float64
#  8   P8            14980 non-null  float64
#  9   T8            14980 non-null  float64
#  10  FC6           14980 non-null  float64
#  11  F4            14980 non-null  float64
#  12  F8            14980 non-null  float64
#  13  AF4           14980 non-null  float64
#  14  eyeDetection  14980 non-null  int64
# dtypes: float64(14), int64(1)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#                  AF3            F7            F3            FC5            T7  \
# count   14980.000000  14980.000000  14980.000000   14980.000000  14980.000000
# mean     4321.917777   4009.767694   4264.022433    4164.946326   4341.741075
# std      2492.072174     45.941672     44.428052    5216.404632     34.738821
# min      1030.770000   2830.770000   1040.000000    2453.330000   2089.740000
# 25%      4280.510000   3990.770000   4250.260000    4108.210000   4331.790000
# 50%      4294.360000   4005.640000   4262.560000    4120.510000   4338.970000
# 75%      4311.790000   4023.080000   4270.770000    4132.310000   4347.180000
# max    309231.000000   7804.620000   6880.510000  642564.000000   6474.360000
#
#                   P7             O1            O2             P8  \
# count   14980.000000   14980.000000  14980.000000   14980.000000
# mean     4644.022379    4110.400160   4616.056904    4218.826610
# std      2924.789537    4600.926543     29.292603    2136.408523
# min      2768.210000    2086.150000   4567.180000    1357.950000
# 25%      4611.790000    4057.950000   4604.620000    4190.770000
# 50%      4617.950000    4070.260000   4613.330000    4199.490000
# 75%      4626.670000    4083.590000   4624.100000    4209.230000
# max    362564.000000  567179.000000   7264.100000  265641.000000
#
#                  T8           FC6            F4             F8            AF4  \
# count  14980.000000  14980.000000  14980.000000   14980.000000   14980.000000
# mean    4231.316200   4202.456900   4279.232774    4615.205336    4416.435832
# std       38.050903     37.785981     41.544312    1208.369958    5891.285043
# min     1816.410000   3273.330000   2257.950000      86.666700    1366.150000
# 25%     4220.510000   4190.260000   4267.690000    4590.770000    4342.050000
# 50%     4229.230000   4200.510000   4276.920000    4603.080000    4354.870000
# 75%     4239.490000   4211.280000   4287.180000    4617.440000    4372.820000
# max     6674.360000   6823.080000   7002.560000  152308.000000  715897.000000
#
#        eyeDetection
# count  14980.000000
# mean       0.448798
# std        0.497388
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# AF3             0
# F7              0
# F3              0
# FC5             0
# T7              0
# P7              0
# O1              0
# O2              0
# P8              0
# T8              0
# FC6             0
# F4              0
# F8              0
# AF4             0
# eyeDetection    0
# dtype: int64

# %%
plt.figure(figsize = (15,15))
cor_matrix = df.corr()
sns.heatmap(cor_matrix,annot=True)
# Out:
# <Axes: >

# %%
# Plotting target distribution 
plt.figure(figsize=(6,6))
df['eyeDetection'].value_counts().plot.pie(explode=[0.1,0.1], autopct='%1.1f%%', shadow=True, textprops={'fontsize':16}).set_title("Target distribution")
# Out:
# Text(0.5, 1.0, 'Target distribution')

# %%
data = df.copy()
y= data.pop('eyeDetection')
x= data

# %%
x_new = StandardScaler().fit_transform(x)

# %%
x_new = pd.DataFrame(x_new) 
x_new.columns = x.columns

# %% [markdown]
# ## Dividing into Training and Validation sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x_new,y,test_size=0.15)

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12733, 14), (2247, 14), (12733,), (2247,))

# %% [markdown]
# ## Reshaping the data as required by the model

# %%
x_train = np.array(x_train).reshape(-1,14,1)
x_test = np.array(x_test).reshape(-1,14,1)

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12733, 14, 1), (2247, 14, 1), (12733,), (2247,))

# %% [markdown]
# ## Defining the Model's architecture

# %%
inputs = tf.keras.Input(shape=(14,1))

Dense1 = Dense(64, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(inputs)

#Dense2 = Dense(128, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(Dense1)
#Dense3 = Dense(256, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(Dense2)

lstm_1=  Bidirectional(LSTM(256, return_sequences = True))(Dense1)
drop = Dropout(0.3)(lstm_1)
lstm_3=  Bidirectional(LSTM(128, return_sequences = True))(drop)
drop2 = Dropout(0.3)(lstm_3)

flat = Flatten()(drop2)

#Dense_1 = Dense(256, activation = 'relu')(flat)

Dense_2 = Dense(128, activation = 'relu')(flat)
outputs = Dense(1, activation='sigmoid')(Dense_2)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 14, 1)]           0
#
#  dense (Dense)               (None, 14, 64)            128
#
#  bidirectional (Bidirection  (None, 14, 512)           657408
#  al)
#
#  dropout (Dropout)           (None, 14, 512)           0
#
#  bidirectional_1 (Bidirecti  (None, 14, 256)           656384
#  onal)
#
#  dropout_1 (Dropout)         (None, 14, 256)           0
#
#  flatten (Flatten)           (None, 3584)              0
#
#  dense_1 (Dense)             (None, 128)               458880
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1772929 (6.76 MB)
# Trainable params: 1772929 (6.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# The loss function used will be 'Binary CrossEntropy'. We will be using callback functions like Early_Stopping to avoid overfitting and lr_scheduler to change the learning rate while model trains.

# %%
def train_model(model,x_train, y_train,x_test,y_test, save_to, epoch = 2):

        opt_adam = keras.optimizers.Adam(learning_rate=0.001)

        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
        mc = ModelCheckpoint(save_to + '_best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.001 * np.exp(-epoch / 10.))
        
        model.compile(optimizer=opt_adam,
                  loss=['binary_crossentropy'],
                  metrics=['accuracy'])
        
        history = model.fit(x_train,y_train,
                        batch_size=20,
                        epochs=epoch,
                        validation_data=(x_test,y_test),
                        callbacks=[es,mc,lr_schedule])
        
        saved_model = load_model(save_to + '_best_model.h5')
        
        return model,history

# %% [markdown]
# ## Analyzing the results.

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# ### Classification Report

# %%
model,history = train_model(model, x_train, y_train,x_test, y_test, save_to= './', epoch = 100)
# Out:
# Epoch 1/100
# 637/637 [==============================] - ETA: 0s - loss: 0.6774 - accuracy: 0.5731
# Epoch 1: val_accuracy improved from -inf to 0.61727, saving model to .\_best_model.h5
# 637/637 [==============================] - 55s 72ms/step - loss: 0.6774 - accuracy: 0.5731 - val_loss: 0.6492 - val_accuracy: 0.6173 - lr: 0.0010
# Epoch 2/100
# 637/637 [==============================] - ETA: 0s - loss: 0.6467 - accuracy: 0.6057
# Epoch 2: val_accuracy improved from 0.61727 to 0.65866, saving model to .\_best_model.h5
# 637/637 [==============================] - 49s 78ms/step - loss: 0.6467 - accuracy: 0.6057 - val_loss: 0.6029 - val_accuracy: 0.6587 - lr: 9.0484e-04
# Epoch 3/100
# 637/637 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.6620
# Epoch 3: val_accuracy improved from 0.65866 to 0.68892, saving model to .\_best_model.h5
# 637/637 [==============================] - 52s 81ms/step - loss: 0.6023 - accuracy: 0.6620 - val_loss: 0.5696 - val_accuracy: 0.6889 - lr: 8.1873e-04
# Epoch 4/100
# 637/637 [==============================] - ETA: 0s - loss: 0.5462 - accuracy: 0.7215
# Epoch 4: val_accuracy improved from 0.68892 to 0.72408, saving model to .\_best_model.h5
# 637/637 [==============================] - 55s 86ms/step - loss: 0.5462 - accuracy: 0.7215 - val_loss: 0.5373 - val_accuracy: 0.7241 - lr: 7.4082e-04
# Epoch 5/100
# 637/637 [==============================] - ETA: 0s - loss: 0.5068 - accuracy: 0.7463
# Epoch 5: val_accuracy improved from 0.72408 to 0.75033, saving model to .\_best_model.h5
# 637/637 [==============================] - 62s 97ms/step - loss: 0.5068 - accuracy: 0.7463 - val_loss: 0.4902 - val_accuracy: 0.7503 - lr: 6.7032e-04
# Epoch 6/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.7653
# Epoch 6: val_accuracy improved from 0.75033 to 0.76057, saving model to .\_best_model.h5
# 637/637 [==============================] - 62s 98ms/step - loss: 0.4726 - accuracy: 0.7653 - val_loss: 0.4810 - val_accuracy: 0.7606 - lr: 6.0653e-04
# Epoch 7/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4475 - accuracy: 0.7825
# Epoch 7: val_accuracy improved from 0.76057 to 0.79217, saving model to .\_best_model.h5
# 637/637 [==============================] - 62s 97ms/step - loss: 0.4475 - accuracy: 0.7825 - val_loss: 0.4370 - val_accuracy: 0.7922 - lr: 5.4881e-04
# Epoch 8/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8026
# Epoch 8: val_accuracy improved from 0.79217 to 0.79439, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.4221 - accuracy: 0.8026 - val_loss: 0.4330 - val_accuracy: 0.7944 - lr: 4.9659e-04
# Epoch 9/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4025 - accuracy: 0.8088
# Epoch 9: val_accuracy improved from 0.79439 to 0.79662, saving model to .\_best_model.h5
# 637/637 [==============================] - 65s 101ms/step - loss: 0.4025 - accuracy: 0.8088 - val_loss: 0.4220 - val_accuracy: 0.7966 - lr: 4.4933e-04
# Epoch 10/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.8188
# Epoch 10: val_accuracy improved from 0.79662 to 0.80952, saving model to .\_best_model.h5
# 637/637 [==============================] - 65s 103ms/step - loss: 0.3885 - accuracy: 0.8188 - val_loss: 0.4062 - val_accuracy: 0.8095 - lr: 4.0657e-04
# Epoch 11/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8267
# Epoch 11: val_accuracy did not improve from 0.80952
# 637/637 [==============================] - 63s 99ms/step - loss: 0.3711 - accuracy: 0.8267 - val_loss: 0.3920 - val_accuracy: 0.8073 - lr: 3.6788e-04
# Epoch 12/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8362
# Epoch 12: val_accuracy improved from 0.80952 to 0.81887, saving model to .\_best_model.h5
# 637/637 [==============================] - 59s 93ms/step - loss: 0.3575 - accuracy: 0.8362 - val_loss: 0.3888 - val_accuracy: 0.8189 - lr: 3.3287e-04
# Epoch 13/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8426
# Epoch 13: val_accuracy improved from 0.81887 to 0.82109, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.3470 - accuracy: 0.8426 - val_loss: 0.3741 - val_accuracy: 0.8211 - lr: 3.0119e-04
# Epoch 14/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.8495
# Epoch 14: val_accuracy improved from 0.82109 to 0.82777, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.3311 - accuracy: 0.8495 - val_loss: 0.3838 - val_accuracy: 0.8278 - lr: 2.7253e-04
# Epoch 15/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.8558
# Epoch 15: val_accuracy did not improve from 0.82777
# 637/637 [==============================] - 64s 100ms/step - loss: 0.3210 - accuracy: 0.8558 - val_loss: 0.3919 - val_accuracy: 0.8215 - lr: 2.4660e-04
# Epoch 16/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8613
# Epoch 16: val_accuracy did not improve from 0.82777
# 637/637 [==============================] - 60s 94ms/step - loss: 0.3138 - accuracy: 0.8613 - val_loss: 0.3733 - val_accuracy: 0.8220 - lr: 2.2313e-04
# Epoch 17/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8645
# Epoch 17: val_accuracy improved from 0.82777 to 0.83222, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.3059 - accuracy: 0.8645 - val_loss: 0.3606 - val_accuracy: 0.8322 - lr: 2.0190e-04
# Epoch 18/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2919 - accuracy: 0.8724
# Epoch 18: val_accuracy improved from 0.83222 to 0.83979, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.2919 - accuracy: 0.8724 - val_loss: 0.3593 - val_accuracy: 0.8398 - lr: 1.8268e-04
# Epoch 19/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.8733
# Epoch 19: val_accuracy did not improve from 0.83979
# 637/637 [==============================] - 63s 99ms/step - loss: 0.2892 - accuracy: 0.8733 - val_loss: 0.3473 - val_accuracy: 0.8398 - lr: 1.6530e-04
# Epoch 20/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.8748
# Epoch 20: val_accuracy improved from 0.83979 to 0.84691, saving model to .\_best_model.h5
# 637/637 [==============================] - 60s 94ms/step - loss: 0.2839 - accuracy: 0.8748 - val_loss: 0.3400 - val_accuracy: 0.8469 - lr: 1.4957e-04
# Epoch 21/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.8763
# Epoch 21: val_accuracy improved from 0.84691 to 0.85091, saving model to .\_best_model.h5
# 637/637 [==============================] - 63s 98ms/step - loss: 0.2755 - accuracy: 0.8763 - val_loss: 0.3435 - val_accuracy: 0.8509 - lr: 1.3534e-04
# Epoch 22/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8828
# Epoch 22: val_accuracy did not improve from 0.85091
# 637/637 [==============================] - 61s 96ms/step - loss: 0.2663 - accuracy: 0.8828 - val_loss: 0.3414 - val_accuracy: 0.8469 - lr: 1.2246e-04
# Epoch 23/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.8850
# Epoch 23: val_accuracy did not improve from 0.85091
# 637/637 [==============================] - 62s 97ms/step - loss: 0.2622 - accuracy: 0.8850 - val_loss: 0.3427 - val_accuracy: 0.8429 - lr: 1.1080e-04
# Epoch 24/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.8875
# Epoch 24: val_accuracy did not improve from 0.85091
# 637/637 [==============================] - 59s 93ms/step - loss: 0.2583 - accuracy: 0.8875 - val_loss: 0.3375 - val_accuracy: 0.8505 - lr: 1.0026e-04
# Epoch 25/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2549 - accuracy: 0.8886
# Epoch 25: val_accuracy improved from 0.85091 to 0.85269, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.2549 - accuracy: 0.8886 - val_loss: 0.3388 - val_accuracy: 0.8527 - lr: 9.0718e-05
# Epoch 26/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.8894
# Epoch 26: val_accuracy did not improve from 0.85269
# 637/637 [==============================] - 62s 98ms/step - loss: 0.2531 - accuracy: 0.8894 - val_loss: 0.3364 - val_accuracy: 0.8496 - lr: 8.2085e-05
# Epoch 27/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.8918
# Epoch 27: val_accuracy did not improve from 0.85269
# 637/637 [==============================] - 90s 141ms/step - loss: 0.2466 - accuracy: 0.8918 - val_loss: 0.3391 - val_accuracy: 0.8482 - lr: 7.4274e-05
# Epoch 28/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.8920
# Epoch 28: val_accuracy did not improve from 0.85269
# 637/637 [==============================] - 59s 93ms/step - loss: 0.2460 - accuracy: 0.8920 - val_loss: 0.3325 - val_accuracy: 0.8509 - lr: 6.7206e-05
# Epoch 29/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.8960
# Epoch 29: val_accuracy improved from 0.85269 to 0.85403, saving model to .\_best_model.h5
# 637/637 [==============================] - 59s 93ms/step - loss: 0.2404 - accuracy: 0.8960 - val_loss: 0.3300 - val_accuracy: 0.8540 - lr: 6.0810e-05
# Epoch 30/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9008
# Epoch 30: val_accuracy improved from 0.85403 to 0.85447, saving model to .\_best_model.h5
# 637/637 [==============================] - 64s 101ms/step - loss: 0.2364 - accuracy: 0.9008 - val_loss: 0.3291 - val_accuracy: 0.8545 - lr: 5.5023e-05
# Epoch 31/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.8970
# Epoch 31: val_accuracy did not improve from 0.85447
# 637/637 [==============================] - 63s 99ms/step - loss: 0.2349 - accuracy: 0.8970 - val_loss: 0.3328 - val_accuracy: 0.8505 - lr: 4.9787e-05
# Epoch 32/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9011
# Epoch 32: val_accuracy improved from 0.85447 to 0.85492, saving model to .\_best_model.h5
# 637/637 [==============================] - 62s 97ms/step - loss: 0.2312 - accuracy: 0.9011 - val_loss: 0.3317 - val_accuracy: 0.8549 - lr: 4.5049e-05
# Epoch 33/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9018
# Epoch 33: val_accuracy did not improve from 0.85492
# 637/637 [==============================] - 70s 109ms/step - loss: 0.2326 - accuracy: 0.9018 - val_loss: 0.3334 - val_accuracy: 0.8536 - lr: 4.0762e-05
# Epoch 34/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9014
# Epoch 34: val_accuracy did not improve from 0.85492
# 637/637 [==============================] - 79s 125ms/step - loss: 0.2302 - accuracy: 0.9014 - val_loss: 0.3319 - val_accuracy: 0.8540 - lr: 3.6883e-05
# Epoch 35/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9002
# Epoch 35: val_accuracy did not improve from 0.85492
# 637/637 [==============================] - 69s 108ms/step - loss: 0.2265 - accuracy: 0.9002 - val_loss: 0.3318 - val_accuracy: 0.8540 - lr: 3.3373e-05
# Epoch 36/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9018
# Epoch 36: val_accuracy did not improve from 0.85492
# 637/637 [==============================] - 65s 102ms/step - loss: 0.2247 - accuracy: 0.9018 - val_loss: 0.3337 - val_accuracy: 0.8545 - lr: 3.0197e-05
# Epoch 37/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9003
# Epoch 37: val_accuracy did not improve from 0.85492
# 637/637 [==============================] - 65s 103ms/step - loss: 0.2265 - accuracy: 0.9003 - val_loss: 0.3316 - val_accuracy: 0.8549 - lr: 2.7324e-05
# Epoch 38/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9047
# Epoch 38: val_accuracy improved from 0.85492 to 0.85536, saving model to .\_best_model.h5
# 637/637 [==============================] - 63s 99ms/step - loss: 0.2220 - accuracy: 0.9047 - val_loss: 0.3324 - val_accuracy: 0.8554 - lr: 2.4724e-05
# Epoch 39/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9050
# Epoch 39: val_accuracy improved from 0.85536 to 0.85714, saving model to .\_best_model.h5
# 637/637 [==============================] - 64s 101ms/step - loss: 0.2227 - accuracy: 0.9050 - val_loss: 0.3303 - val_accuracy: 0.8571 - lr: 2.2371e-05
# Epoch 40/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9064
# Epoch 40: val_accuracy improved from 0.85714 to 0.85848, saving model to .\_best_model.h5
# 637/637 [==============================] - 61s 96ms/step - loss: 0.2198 - accuracy: 0.9064 - val_loss: 0.3320 - val_accuracy: 0.8585 - lr: 2.0242e-05
# Epoch 40: early stopping

# %%
y_pred =model.predict(x_test)
y_pred = np.array(y_pred >= 0.5, dtype = np.int32)
confusion_matrix(y_test, y_pred)
# Out:
# 71/71 [==============================] - 2s 33ms/step
# array([[1128,  150],
#        [ 168,  801]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      1278
#            1       0.84      0.83      0.83       969
#
#     accuracy                           0.86      2247
#    macro avg       0.86      0.85      0.86      2247
# weighted avg       0.86      0.86      0.86      2247

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Analyzing the results

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred =model.predict(x_test)
y_pred = np.array(y_pred >= 0.5, dtype = np.int32)
confusion_matrix(y_test, y_pred)
# Out:
# 71/71 [==============================] - 3s 46ms/step
# array([[1128,  150],
#        [ 168,  801]], dtype=int64)

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      1278
#            1       0.84      0.83      0.83       969
#
#     accuracy                           0.86      2247
#    macro avg       0.86      0.85      0.86      2247
# weighted avg       0.86      0.86      0.86      2247
