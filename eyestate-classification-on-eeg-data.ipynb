# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import tensorflow.compat.v1 as tf
from sklearn.metrics import confusion_matrix
import numpy as np
from scipy.io import loadmat
import os
from pywt import wavedec
from functools import reduce
from scipy import signal
from scipy.stats import entropy
from scipy.fft import fft, ifft
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tensorflow import keras as K
import matplotlib.pyplot as plt
import scipy
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold,cross_validate
from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape
#from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt;
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.decomposition import PCA
from tensorflow import keras
from sklearn.model_selection import cross_val_score
from tensorflow.keras.layers import Conv1D,Conv2D,Add
from tensorflow.keras.layers import MaxPool1D, MaxPooling2D
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("EEG_Eye_State_Classification.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14980 entries, 0 to 14979
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AF3           14980 non-null  float64
#  1   F7            14980 non-null  float64
#  2   F3            14980 non-null  float64
#  3   FC5           14980 non-null  float64
#  4   T7            14980 non-null  float64
#  5   P7            14980 non-null  float64
#  6   O1            14980 non-null  float64
#  7   O2            14980 non-null  float64
#  8   P8            14980 non-null  float64
#  9   T8            14980 non-null  float64
#  10  FC6           14980 non-null  float64
#  11  F4            14980 non-null  float64
#  12  F8            14980 non-null  float64
#  13  AF4           14980 non-null  float64
#  14  eyeDetection  14980 non-null  int64
# dtypes: float64(14), int64(1)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#                  AF3            F7            F3            FC5            T7  \
# count   14980.000000  14980.000000  14980.000000   14980.000000  14980.000000
# mean     4321.917777   4009.767694   4264.022433    4164.946326   4341.741075
# std      2492.072174     45.941672     44.428052    5216.404632     34.738821
# min      1030.770000   2830.770000   1040.000000    2453.330000   2089.740000
# 25%      4280.510000   3990.770000   4250.260000    4108.210000   4331.790000
# 50%      4294.360000   4005.640000   4262.560000    4120.510000   4338.970000
# 75%      4311.790000   4023.080000   4270.770000    4132.310000   4347.180000
# max    309231.000000   7804.620000   6880.510000  642564.000000   6474.360000
#
#                   P7             O1            O2             P8  \
# count   14980.000000   14980.000000  14980.000000   14980.000000
# mean     4644.022379    4110.400160   4616.056904    4218.826610
# std      2924.789537    4600.926543     29.292603    2136.408523
# min      2768.210000    2086.150000   4567.180000    1357.950000
# 25%      4611.790000    4057.950000   4604.620000    4190.770000
# 50%      4617.950000    4070.260000   4613.330000    4199.490000
# 75%      4626.670000    4083.590000   4624.100000    4209.230000
# max    362564.000000  567179.000000   7264.100000  265641.000000
#
#                  T8           FC6            F4             F8            AF4  \
# count  14980.000000  14980.000000  14980.000000   14980.000000   14980.000000
# mean    4231.316200   4202.456900   4279.232774    4615.205336    4416.435832
# std       38.050903     37.785981     41.544312    1208.369958    5891.285043
# min     1816.410000   3273.330000   2257.950000      86.666700    1366.150000
# 25%     4220.510000   4190.260000   4267.690000    4590.770000    4342.050000
# 50%     4229.230000   4200.510000   4276.920000    4603.080000    4354.870000
# 75%     4239.490000   4211.280000   4287.180000    4617.440000    4372.820000
# max     6674.360000   6823.080000   7002.560000  152308.000000  715897.000000
#
#        eyeDetection
# count  14980.000000
# mean       0.448798
# std        0.497388
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# AF3             0
# F7              0
# F3              0
# FC5             0
# T7              0
# P7              0
# O1              0
# O2              0
# P8              0
# T8              0
# FC6             0
# F4              0
# F8              0
# AF4             0
# eyeDetection    0
# dtype: int64

# %%
plt.figure(figsize = (15,15))
cor_matrix = df.corr()
sns.heatmap(cor_matrix,annot=True)
# Out:
# <Axes: >

# %%
# Plotting target distribution 
plt.figure(figsize=(6,6))
df['eyeDetection'].value_counts().plot.pie(explode=[0.1,0.1], autopct='%1.1f%%', shadow=True, textprops={'fontsize':16}).set_title("Target distribution")
# Out:
# Text(0.5, 1.0, 'Target distribution')

# %%
data = df.copy()
y= data.pop('eyeDetection')
x= data

# %%
x_new = StandardScaler().fit_transform(x)

# %%
x_new = pd.DataFrame(x_new) 
x_new.columns = x.columns

# %% [markdown]
# ## Dividing into Training and Validation sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x_new,y,test_siz Se=0.15)

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12733, 14), (2247, 14), (12733,), (2247,))

# %% [markdown]
# ## Reshaping the data as required by the model

# %%
x_train = np.array(x_train).reshape(-1,14,1)
x_test = np.array(x_test).reshape(-1,14,1)

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12733, 14, 1), (2247, 14, 1), (12733,), (2247,))

# %% [markdown]
# ## Defining the Model's architecture

# %%
inputs = tf.keras.Input(shape=(14,1))

Dense1 = Dense(64, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(inputs)

#Dense2 = Dense(128, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(Dense1)
#Dense3 = Dense(256, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(Dense2)

lstm_1=  Bidirectional(LSTM(256, return_sequences = True))(Dense1)
drop = Dropout(0.3)(lstm_1)
lstm_3=  Bidirectional(LSTM(128, return_sequences = True))(drop)
drop2 = Dropout(0.3)(lstm_3)

flat = Flatten()(drop2)

#Dense_1 = Dense(256, activation = 'relu')(flat)

Dense_2 = Dense(128, activation = 'relu')(flat)
outputs = Dense(1, activation='sigmoid')(Dense_2)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 14, 1)]           0
#
#  dense (Dense)               (None, 14, 64)            128
#
#  bidirectional (Bidirection  (None, 14, 512)           657408
#  al)
#
#  dropout (Dropout)           (None, 14, 512)           0
#
#  bidirectional_1 (Bidirecti  (None, 14, 256)           656384
#  onal)
#
#  dropout_1 (Dropout)         (None, 14, 256)           0
#
#  flatten (Flatten)           (None, 3584)              0
#
#  dense_1 (Dense)             (None, 128)               458880
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1772929 (6.76 MB)
# Trainable params: 1772929 (6.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# The loss function used will be 'Binary CrossEntropy'. We will be using callback functions like Early_Stopping to avoid overfitting and lr_scheduler to change the learning rate while model trains.

# %%
def train_model(model,x_train, y_train,x_test,y_test, save_to, epoch = 2):

        opt_adam = keras.optimizers.Adam(learning_rate=0.001)

        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
        mc = ModelCheckpoint(save_to + '_best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.001 * np.exp(-epoch / 10.))
        
        model.compile(optimizer=opt_adam,
                  loss=['binary_crossentropy'],
                  metrics=['accuracy'])
        
        history = model.fit(x_train,y_train,
                        batch_size=20,
                        epochs=epoch,
                        validation_data=(x_test,y_test),
                        callbacks=[es,mc,lr_schedule])
        
        saved_model = load_model(save_to + '_best_model.h5')
        
        return model,history

# %% [markdown]
# ## Analyzing the results.

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# ### Classification Report

# %%
model,history = train_model(model, x_train, y_train,x_test, y_test, save_to= './', epoch = 100)
# Out:
# Epoch 1/100
# 637/637 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.5735
# Epoch 1: val_accuracy improved from -inf to 0.59680, saving model to .\_best_model.h5
# 637/637 [==============================] - 79s 107ms/step - loss: 0.6769 - accuracy: 0.5735 - val_loss: 0.6719 - val_accuracy: 0.5968 - lr: 0.0010
# Epoch 2/100
# 637/637 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.6072
# Epoch 2: val_accuracy improved from 0.59680 to 0.60970, saving model to .\_best_model.h5
# 637/637 [==============================] - 70s 110ms/step - loss: 0.6478 - accuracy: 0.6072 - val_loss: 0.6446 - val_accuracy: 0.6097 - lr: 9.0484e-04
# Epoch 3/100
# 637/637 [==============================] - ETA: 0s - loss: 0.6207 - accuracy: 0.6393
# Epoch 3: val_accuracy improved from 0.60970 to 0.64619, saving model to .\_best_model.h5
# 637/637 [==============================] - 67s 105ms/step - loss: 0.6207 - accuracy: 0.6393 - val_loss: 0.6093 - val_accuracy: 0.6462 - lr: 8.1873e-04
# Epoch 4/100
# 637/637 [==============================] - ETA: 0s - loss: 0.5751 - accuracy: 0.6898
# Epoch 4: val_accuracy improved from 0.64619 to 0.72185, saving model to .\_best_model.h5
# 637/637 [==============================] - 68s 107ms/step - loss: 0.5751 - accuracy: 0.6898 - val_loss: 0.5434 - val_accuracy: 0.7219 - lr: 7.4082e-04
# Epoch 5/100
# 637/637 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.7310
# Epoch 5: val_accuracy improved from 0.72185 to 0.75968, saving model to .\_best_model.h5
# 637/637 [==============================] - 68s 107ms/step - loss: 0.5239 - accuracy: 0.7310 - val_loss: 0.4949 - val_accuracy: 0.7597 - lr: 6.7032e-04
# Epoch 6/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7573
# Epoch 6: val_accuracy improved from 0.75968 to 0.76814, saving model to .\_best_model.h5
# 637/637 [==============================] - 66s 103ms/step - loss: 0.4857 - accuracy: 0.7573 - val_loss: 0.4686 - val_accuracy: 0.7681 - lr: 6.0653e-04
# Epoch 7/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4534 - accuracy: 0.7782
# Epoch 7: val_accuracy improved from 0.76814 to 0.78505, saving model to .\_best_model.h5
# 637/637 [==============================] - 69s 108ms/step - loss: 0.4534 - accuracy: 0.7782 - val_loss: 0.4613 - val_accuracy: 0.7850 - lr: 5.4881e-04
# Epoch 8/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4303 - accuracy: 0.7962
# Epoch 8: val_accuracy improved from 0.78505 to 0.79929, saving model to .\_best_model.h5
# 637/637 [==============================] - 68s 106ms/step - loss: 0.4303 - accuracy: 0.7962 - val_loss: 0.4409 - val_accuracy: 0.7993 - lr: 4.9659e-04
# Epoch 9/100
# 637/637 [==============================] - ETA: 0s - loss: 0.4069 - accuracy: 0.8042
# Epoch 9: val_accuracy improved from 0.79929 to 0.80641, saving model to .\_best_model.h5
# 637/637 [==============================] - 69s 108ms/step - loss: 0.4069 - accuracy: 0.8042 - val_loss: 0.4298 - val_accuracy: 0.8064 - lr: 4.4933e-04
# Epoch 10/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3936 - accuracy: 0.8167
# Epoch 10: val_accuracy improved from 0.80641 to 0.80952, saving model to .\_best_model.h5
# 637/637 [==============================] - 70s 111ms/step - loss: 0.3936 - accuracy: 0.8167 - val_loss: 0.4184 - val_accuracy: 0.8095 - lr: 4.0657e-04
# Epoch 11/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3778 - accuracy: 0.8265
# Epoch 11: val_accuracy improved from 0.80952 to 0.81486, saving model to .\_best_model.h5
# 637/637 [==============================] - 71s 112ms/step - loss: 0.3778 - accuracy: 0.8265 - val_loss: 0.4102 - val_accuracy: 0.8149 - lr: 3.6788e-04
# Epoch 12/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.8351
# Epoch 12: val_accuracy did not improve from 0.81486
# 637/637 [==============================] - 71s 111ms/step - loss: 0.3610 - accuracy: 0.8351 - val_loss: 0.4208 - val_accuracy: 0.8042 - lr: 3.3287e-04
# Epoch 13/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3522 - accuracy: 0.8422
# Epoch 13: val_accuracy did not improve from 0.81486
# 637/637 [==============================] - 62s 97ms/step - loss: 0.3522 - accuracy: 0.8422 - val_loss: 0.4042 - val_accuracy: 0.8135 - lr: 3.0119e-04
# Epoch 14/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3415 - accuracy: 0.8492
# Epoch 14: val_accuracy improved from 0.81486 to 0.82287, saving model to .\_best_model.h5
# 637/637 [==============================] - 65s 103ms/step - loss: 0.3415 - accuracy: 0.8492 - val_loss: 0.3957 - val_accuracy: 0.8229 - lr: 2.7253e-04
# Epoch 15/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8510
# Epoch 15: val_accuracy did not improve from 0.82287
# 637/637 [==============================] - 67s 105ms/step - loss: 0.3305 - accuracy: 0.8510 - val_loss: 0.3927 - val_accuracy: 0.8224 - lr: 2.4660e-04
# Epoch 16/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3263 - accuracy: 0.8514
# Epoch 16: val_accuracy did not improve from 0.82287
# 637/637 [==============================] - 66s 104ms/step - loss: 0.3263 - accuracy: 0.8514 - val_loss: 0.4082 - val_accuracy: 0.8153 - lr: 2.2313e-04
# Epoch 17/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8575
# Epoch 17: val_accuracy did not improve from 0.82287
# 637/637 [==============================] - 63s 99ms/step - loss: 0.3175 - accuracy: 0.8575 - val_loss: 0.3946 - val_accuracy: 0.8202 - lr: 2.0190e-04
# Epoch 18/100
# 637/637 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 0.8622
# Epoch 18: val_accuracy improved from 0.82287 to 0.83000, saving model to .\_best_model.h5
# 637/637 [==============================] - 70s 109ms/step - loss: 0.3067 - accuracy: 0.8622 - val_loss: 0.3850 - val_accuracy: 0.8300 - lr: 1.8268e-04
# Epoch 19/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.8646
# Epoch 19: val_accuracy improved from 0.83000 to 0.83133, saving model to .\_best_model.h5
# 637/637 [==============================] - 69s 108ms/step - loss: 0.2996 - accuracy: 0.8646 - val_loss: 0.3811 - val_accuracy: 0.8313 - lr: 1.6530e-04
# Epoch 20/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.8670
# Epoch 20: val_accuracy improved from 0.83133 to 0.83489, saving model to .\_best_model.h5
# 637/637 [==============================] - 69s 108ms/step - loss: 0.2978 - accuracy: 0.8670 - val_loss: 0.3776 - val_accuracy: 0.8349 - lr: 1.4957e-04
# Epoch 21/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.8695
# Epoch 21: val_accuracy did not improve from 0.83489
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2915 - accuracy: 0.8695 - val_loss: 0.3865 - val_accuracy: 0.8296 - lr: 1.3534e-04
# Epoch 22/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8748
# Epoch 22: val_accuracy improved from 0.83489 to 0.83756, saving model to .\_best_model.h5
# 637/637 [==============================] - 66s 104ms/step - loss: 0.2832 - accuracy: 0.8748 - val_loss: 0.3772 - val_accuracy: 0.8376 - lr: 1.2246e-04
# Epoch 23/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8756
# Epoch 23: val_accuracy did not improve from 0.83756
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2803 - accuracy: 0.8756 - val_loss: 0.3799 - val_accuracy: 0.8318 - lr: 1.1080e-04
# Epoch 24/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8787
# Epoch 24: val_accuracy improved from 0.83756 to 0.84068, saving model to .\_best_model.h5
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2739 - accuracy: 0.8787 - val_loss: 0.3756 - val_accuracy: 0.8407 - lr: 1.0026e-04
# Epoch 25/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.8816
# Epoch 25: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 69s 108ms/step - loss: 0.2703 - accuracy: 0.8816 - val_loss: 0.3786 - val_accuracy: 0.8322 - lr: 9.0718e-05
# Epoch 26/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.8820
# Epoch 26: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2689 - accuracy: 0.8820 - val_loss: 0.3729 - val_accuracy: 0.8371 - lr: 8.2085e-05
# Epoch 27/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.8860
# Epoch 27: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 69s 108ms/step - loss: 0.2642 - accuracy: 0.8860 - val_loss: 0.3723 - val_accuracy: 0.8376 - lr: 7.4274e-05
# Epoch 28/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.8848
# Epoch 28: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 68s 106ms/step - loss: 0.2603 - accuracy: 0.8848 - val_loss: 0.3721 - val_accuracy: 0.8340 - lr: 6.7206e-05
# Epoch 29/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.8871
# Epoch 29: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 65s 102ms/step - loss: 0.2577 - accuracy: 0.8871 - val_loss: 0.3732 - val_accuracy: 0.8402 - lr: 6.0810e-05
# Epoch 30/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.8908
# Epoch 30: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2524 - accuracy: 0.8908 - val_loss: 0.3771 - val_accuracy: 0.8349 - lr: 5.5023e-05
# Epoch 31/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2523 - accuracy: 0.8908
# Epoch 31: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 65s 102ms/step - loss: 0.2523 - accuracy: 0.8908 - val_loss: 0.3757 - val_accuracy: 0.8362 - lr: 4.9787e-05
# Epoch 32/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.8933
# Epoch 32: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 68s 106ms/step - loss: 0.2493 - accuracy: 0.8933 - val_loss: 0.3693 - val_accuracy: 0.8398 - lr: 4.5049e-05
# Epoch 33/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.8911
# Epoch 33: val_accuracy did not improve from 0.84068
# 637/637 [==============================] - 63s 99ms/step - loss: 0.2486 - accuracy: 0.8911 - val_loss: 0.3734 - val_accuracy: 0.8407 - lr: 4.0762e-05
# Epoch 34/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.8921
# Epoch 34: val_accuracy improved from 0.84068 to 0.84424, saving model to .\_best_model.h5
# 637/637 [==============================] - 66s 104ms/step - loss: 0.2456 - accuracy: 0.8921 - val_loss: 0.3696 - val_accuracy: 0.8442 - lr: 3.6883e-05
# Epoch 35/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.8955
# Epoch 35: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 65s 103ms/step - loss: 0.2450 - accuracy: 0.8955 - val_loss: 0.3697 - val_accuracy: 0.8402 - lr: 3.3373e-05
# Epoch 36/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.8922
# Epoch 36: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2478 - accuracy: 0.8922 - val_loss: 0.3703 - val_accuracy: 0.8433 - lr: 3.0197e-05
# Epoch 37/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.8991
# Epoch 37: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 378s 594ms/step - loss: 0.2392 - accuracy: 0.8991 - val_loss: 0.3721 - val_accuracy: 0.8385 - lr: 2.7324e-05
# Epoch 38/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.8977
# Epoch 38: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 47s 73ms/step - loss: 0.2403 - accuracy: 0.8977 - val_loss: 0.3738 - val_accuracy: 0.8393 - lr: 2.4724e-05
# Epoch 39/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.8993
# Epoch 39: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 50s 79ms/step - loss: 0.2367 - accuracy: 0.8993 - val_loss: 0.3720 - val_accuracy: 0.8376 - lr: 2.2371e-05
# Epoch 40/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9003
# Epoch 40: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 53s 83ms/step - loss: 0.2344 - accuracy: 0.9003 - val_loss: 0.3730 - val_accuracy: 0.8371 - lr: 2.0242e-05
# Epoch 41/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.8979
# Epoch 41: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 56s 88ms/step - loss: 0.2352 - accuracy: 0.8979 - val_loss: 0.3729 - val_accuracy: 0.8385 - lr: 1.8316e-05
# Epoch 42/100
# 637/637 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.8997
# Epoch 42: val_accuracy did not improve from 0.84424
# 637/637 [==============================] - 58s 92ms/step - loss: 0.2376 - accuracy: 0.8997 - val_loss: 0.3711 - val_accuracy: 0.8402 - lr: 1.6573e-05
# Epoch 42: early stopping

# %%
y_pred =model.predict(x_test)
y_pred = np.array(y_pred >= 0.5, dtype = np.int32)
confusion_matrix(y_test, y_pred)
# Out:
# 71/71 [==============================] - 5s 34ms/step
# array([[1057,  185],
#        [ 174,  831]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85      1242
#            1       0.82      0.83      0.82      1005
#
#     accuracy                           0.84      2247
#    macro avg       0.84      0.84      0.84      2247
# weighted avg       0.84      0.84      0.84      2247

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Analyzing the results

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred =model.predict(x_test)
y_pred = np.array(y_pred >= 0.5, d type = np.int32)
confusion_matrix(y_test, y_pred)
# Out:
# 71/71 [==============================] - 2s 33ms/step
# array([[1057,  185],
#        [ 174,  831]], dtype=int64)

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85      1242
#            1       0.82      0.83      0.82      1005
#
#     accuracy                           0.84      2247
#    macro avg       0.84      0.84      0.84      2247
# weighted avg       0.84      0.84      0.84      2247
